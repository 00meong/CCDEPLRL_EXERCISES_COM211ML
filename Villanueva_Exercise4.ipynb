# %% [markdown]
# # Exercise 4

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np
import pandas as pd

dataset = pd.read_json('reviews.json')

# %%
dataset.head()
# Out:
#                                               review  rating
# 0                    sir okay armygreen shorts nice        5
# 1  di pareha yong mga size nila may sobrang liit ...       5
# 2  super worth it ang ganda Sombra grabi order na...       5
# 3                                   ganda po salamat       5
# 4                maayos pagkadeliver maganda den sya       5

# %%
mask = (dataset['rating'] > 0 ) & (dataset['rating'] <4)
column_name = 'rating'
dataset.loc[mask, column_name] = 0

mask = (dataset['rating'] > 3 ) & (dataset['rating'] < 6)
column_name = 'rating'
dataset.loc[mask, column_name] = 1

dataset.head()
# Out:
#                                               review  rating
# 0                    sir okay armygreen shorts nice        1
# 1  di pareha yong mga size nila may sobrang liit ...       1
# 2  super worth it ang ganda Sombra grabi order na...       1
# 3                                   ganda po salamat       1
# 4                maayos pagkadeliver maganda den sya       1

# %% [markdown]
# ## 1. Tokenize the data

# %%
review = dataset['review'].tolist()
rating = dataset['rating'].tolist()

# Separate out the review and rating into training and test sets
training_size = int(len(review) * 0.8)

training_review = review[0:training_size]
testing_review = review[training_size:]
training_rating = rating[0:training_size]
testing_rating = rating[training_size:]

# Make labels into numpy arrays for use with the network later
training_rating_final = np.array(training_rating)
testing_rating_final = np.array(testing_rating)

# %%
# answer here

vocab_size = 1000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = ""

# %%
from tensorflow.keras.preprocessing.text import Tokenizer


tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_review)
word_index = tokenizer.word_index

# %% [markdown]
# ## 2. Sequence the data

# %%
# answer here
from tensorflow.keras.preprocessing.sequence import pad_sequences

sequences = tokenizer.texts_to_sequences(training_review)

# %% [markdown]
# ## 3. Pad the data

# %%
# answer here
padded = pad_sequences(sequences,maxlen=max_length, padding=padding_type,
                       truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_review)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length,
                               padding=padding_type, truncating=trunc_type)

# %% [markdown]
# ## 4. Train a sentiment model

# %%
# answer here

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size + 1, 200, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(96, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 200)          200200
#
#  flatten (Flatten)           (None, 20000)             0
#
#  dense (Dense)               (None, 96)                1920096
#
#  dense_1 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 2120393 (8.09 MB)
# Trainable params: 2120393 (8.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_epochs = 25
model.fit(padded, training_rating_final, epochs=num_epochs, validation_data=(testing_padded, testing_rating_final))
# Out:
# Epoch 1/25
# 25/25 [==============================] - 8s 190ms/step - loss: 0.6857 - accuracy: 0.5562 - val_loss: 0.9252 - val_accuracy: 0.2139
# Epoch 2/25
# 25/25 [==============================] - 3s 110ms/step - loss: 0.5424 - accuracy: 0.7862 - val_loss: 0.6644 - val_accuracy: 0.5970
# Epoch 3/25
# 25/25 [==============================] - 3s 136ms/step - loss: 0.3162 - accuracy: 0.9237 - val_loss: 0.5329 - val_accuracy: 0.7363
# Epoch 4/25
# 25/25 [==============================] - 3s 115ms/step - loss: 0.1595 - accuracy: 0.9575 - val_loss: 0.4969 - val_accuracy: 0.7662
# Epoch 5/25
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0889 - accuracy: 0.9750 - val_loss: 0.5872 - val_accuracy: 0.7363
# Epoch 6/25
# 25/25 [==============================] - 1s 37ms/step - loss: 0.0615 - accuracy: 0.9762 - val_loss: 0.7067 - val_accuracy: 0.7164
# Epoch 7/25
# 25/25 [==============================] - 1s 43ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.6908 - val_accuracy: 0.7214
# Epoch 8/25
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0389 - accuracy: 0.9825 - val_loss: 0.7789 - val_accuracy: 0.6965
# Epoch 9/25
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0354 - accuracy: 0.9837 - val_loss: 0.6168 - val_accuracy: 0.7363
# Epoch 10/25
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0358 - accuracy: 0.9825 - val_loss: 0.8727 - val_accuracy: 0.6866
# Epoch 11/25
# 25/25 [==============================] - 1s 29ms/step - loss: 0.0350 - accuracy: 0.9837 - val_loss: 0.7904 - val_accuracy: 0.7313
# Epoch 12/25
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0324 - accuracy: 0.9875 - val_loss: 0.6811 - val_accuracy: 0.7512
# Epoch 13/25
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0307 - accuracy: 0.9850 - val_loss: 0.8316 - val_accuracy: 0.7164
# Epoch 14/25
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0282 - accuracy: 0.9837 - val_loss: 0.8644 - val_accuracy: 0.7065
# Epoch 15/25
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9875 - val_loss: 0.9886 - val_accuracy: 0.6915
# Epoch 16/25
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0255 - accuracy: 0.9850 - val_loss: 0.9362 - val_accuracy: 0.6965
# Epoch 17/25
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0275 - accuracy: 0.9862 - val_loss: 1.0519 - val_accuracy: 0.6866
# Epoch 18/25
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0269 - accuracy: 0.9875 - val_loss: 0.9349 - val_accuracy: 0.6965
# Epoch 19/25
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0280 - accuracy: 0.9862 - val_loss: 0.9405 - val_accuracy: 0.7065
# Epoch 20/25
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0244 - accuracy: 0.9850 - val_loss: 1.0588 - val_accuracy: 0.6816
# Epoch 21/25
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0284 - accuracy: 0.9862 - val_loss: 1.1194 - val_accuracy: 0.6418
# Epoch 22/25
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0238 - accuracy: 0.9887 - val_loss: 0.7023 - val_accuracy: 0.7662
# Epoch 23/25
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0288 - accuracy: 0.9837 - val_loss: 1.0879 - val_accuracy: 0.6866
# Epoch 24/25
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9850 - val_loss: 1.1902 - val_accuracy: 0.6716
# Epoch 25/25
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0255 - accuracy: 0.9787 - val_loss: 1.0146 - val_accuracy: 0.6965

# %% [markdown]
# ## Get files for visualing the network

# %%
# answer here

e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (1001, 200)

# %% [markdown]
# ## 5. Predict sentiment with new reviews

# %%
# answer here

# Use the model to predict a review
fake_reviews = ['Hindi pareho yung kulay',
                'Kulang yung pinadala scam',
                'Maganda yung material hindi manipis',
                'Okay lang pwede na para sa presyo',
                'Sana may freebie',
                'Mali yung size',
                'May sira yung yung damit',
                'Wag na kayo bibili dito panget',
                'Sobrang ganda nagustuhan ng anak ko bibili ako ulit sa susunod',
                'Pang reregalo ko sana kaso di umabot ang bagal ng shipping']

print(fake_reviews)

# Create the sequences
padding_type='post'
sample_sequences = tokenizer.texts_to_sequences(fake_reviews)
fakes_padded = pad_sequences(sample_sequences, padding=padding_type, maxlen=max_length)

print('\nHOT OFF THE PRESS! HERE ARE SOME NEWLY MINTED, ABSOLUTELY GENUINE REVIEWS!\n')

classes = model.predict(fakes_padded)

# The closer the class is to 1, the more positive the review is deemed to be
for x in range(len(fake_reviews)):
  print(fake_reviews[x])
  print(classes[x])
  print('\n')
# Out:
# ['Hindi pareho yung kulay', 'Kulang yung pinadala scam', 'Maganda yung material hindi manipis', 'Okay lang pwede na para sa presyo', 'Sana may freebie', 'Mali yung size', 'May sira yung yung damit', 'Wag na kayo bibili dito panget', 'Sobrang ganda nagustuhan ng anak ko bibili ako ulit sa susunod', 'Pang reregalo ko sana kaso di umabot ang bagal ng shipping']
#
# HOT OFF THE PRESS! HERE ARE SOME NEWLY MINTED, ABSOLUTELY GENUINE REVIEWS!
#
# 1/1 [==============================] - 0s 72ms/step
# Hindi pareho yung kulay
# [0.01144111]
#
#
# Kulang yung pinadala scam
# [0.00041333]
#
#
# Maganda yung material hindi manipis
# [0.95828843]
#
#
# Okay lang pwede na para sa presyo
# [0.99830616]
#
#
# Sana may freebie
# [0.20738398]
#
#
# Mali yung size
# [0.00914251]
#
#
# May sira yung yung damit
# [0.00146853]
#
#
# Wag na kayo bibili dito panget
# [0.11030847]
#
#
# Sobrang ganda nagustuhan ng anak ko bibili ako ulit sa susunod
# [0.9998029]
#
#
# Pang reregalo ko sana kaso di umabot ang bagal ng shipping
# [0.21365428]
